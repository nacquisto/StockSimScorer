# %% [markdown]
# # Schema

# %% [markdown]
# ### Classes/
#     - __init__.py
#
#     - file_handler.py
#         - StockDataFileSelection
#
#     - stock_selection.py
#         - SectorStockSelection
#
#     - date_selection.py
#         - DateSelection
#
#     - fetch_data.py
#         - FetchData
#
#     - chart_data.py
#         - ChartData
#
#     - analysis_type_selection.py
#         - AnalysisTypeSelection
#
#     - technical_analysis.py
#         - TechnicalAnalysis
#
#     - fundamental_analysis.py
#         - FundamentalAnalysis
#
#     - output_path.py
#         - Output
#
#     - user_input_handler.py
#         - UserInputHandler
#
# ### CSV/
#
#     - SP500.csv
#
#     - DOW30.csv
#
#     - NASDAQ.csv
#
#     - RUSSELL2000.csv
#
#     - financialdata.csv
#
#     - stockdata.csv
#
# ### Main.py

# %% [markdown]
# The file_handler.py module contains the StockDataFileSelection class, which is used to select a CSV file containing stock data.
#
# The stock_selection.py module contains the SectorStockSelection class, which is used to select stock symbols from a specific sector.
#
# The fetch_data.py module contains the FetchData class, which is used to fetch historical stock data from Yahoo Finance.
#
# The chart_data.py module contains the ChartData class, which is used to plot the historical stock data.
#
# The analysis_type_selection.py module contains the AnalysisTypeSelection class, which is used to select the type of analysis to perform (technical or fundamental).
#
# The technical_analysis.py module contains the TechnicalAnalysis class, which is used to perform technical analysis on the stock data.
#
# The fundamental_analysis.py module contains the FundamentalAnalysis class, which is used to perform fundamental analysis on the stock data.
#
# The data_display.py module contains the DataDisplay class, which is used to display the stock data and analysis results.
#
# The output_path.py module contains the Output class, which is used to save the stock data and analysis results to CSV files.

# %%
from Classes.user_input_handler import UserInputHandler

def main():
    csv_folder = "CSV"
    input_handler = UserInputHandler(csv_folder)
    stock_data, good_stocks, error_stocks, analysis_data = input_handler.get_user_input()
    input_handler.system_output(stock_data, good_stocks, error_stocks, analysis_data)

if __name__ == "__main__":
    main()
# Out:
# Available stock data files:
# 1: SP500.csv
# 2: DOW30.csv
# 3: RUSSELL2000.csv
# Available sectors:
# 0: Industrials
# 1: Health Care
# 2: Information Technology
# 3: Communication Services
# 4: Consumer Staples
# 5: Consumer Discretionary
# 6: Utilities
# 7: Financials
# 8: Materials
# 9: Real Estate
# 10: Energy
# Selected sector(s): Health Care
# Available stocks in the selected sector(s):
# 0: ABT
# 1: ABBV
# 2: A
# 3: ALGN
# 4: ABC
# 5: AMGN
# 6: BAX
# 7: BDX
# 8: BIO
# 9: TECH
# 10: BIIB
# 11: BSX
# 12: BMY
# 13: CAH
# 14: CTLT
# 15: CNC
# 16: CRL
# 17: CI
# 18: COO
# 19: CVS
# 20: DHR
# 21: DVA
# 22: XRAY
# 23: DXCM
# 24: EW
# 25: ELV
# 26: LLY
# 27: GEHC
# 28: GILD
# 29: HCA
# 30: HSIC
# 31: HOLX
# 32: HUM
# 33: IDXX
# 34: ILMN
# 35: INCY
# 36: PODD
# 37: ISRG
# 38: IQV
# 39: JNJ
# 40: LH
# 41: MCK
# 42: MDT
# 43: MRK
# 44: MTD
# 45: MRNA
# 46: MOH
# 47: OGN
# 48: PKI
# 49: PFE
# 50: DGX
# 51: REGN
# 52: RMD
# 53: STE
# 54: SYK
# 55: TFX
# 56: TMO
# 57: UNH
# 58: UHS
# ...
